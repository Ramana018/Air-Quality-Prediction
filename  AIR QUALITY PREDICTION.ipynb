# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Ramana Reddy (Rakhi)\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv(r"C:\Users\Ramana Reddy (Rakhi)\OneDrive\Desktop\DATA SETS\Air quality project\De,Hyd,Mum,Pat .csv")

# %%
df.head(10)
# Out:
#     City        Date   PM2.5    PM10     NO    NO2     NOx     NH3     CO  \
# 0  Delhi  01-01-2015  313.22  607.98  69.16  36.39  110.59   33.85  15.20
# 1  Delhi  02-01-2015  186.18  269.55  62.09  32.87   88.14   31.83   9.54
# 2  Delhi  03-01-2015   87.18  131.90  25.73  30.31   47.95   69.55  10.61
# 3  Delhi  04-01-2015  151.84  241.84  25.01  36.91   48.62  130.36  11.54
# 4  Delhi  05-01-2015  146.60  219.13  14.01  34.92   38.25  122.88   9.20
# 5  Delhi  06-01-2015  149.58  252.10  17.21  37.84   42.46  134.97   9.44
# 6  Delhi  07-01-2015  217.87  376.51  26.99  40.15   52.41  134.82   9.78
# 7  Delhi  08-01-2015  229.90  360.95  23.34  43.16   51.21  138.13  11.01
# 8  Delhi  09-01-2015  201.66  397.43  19.18  38.56   45.60  140.60  11.09
# 9  Delhi  10-01-2015  221.02  361.74  24.79  46.39   55.19  134.06   9.70
#
#     SO2     O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  9.25  41.68    14.36    24.86    9.84  472     Severe
# ...

# %%
df.tail(10)
# Out:
#        City        Date  PM2.5   PM10     NO    NO2    NOx   NH3    CO   SO2  \
# 3686  Patna  22-06-2020  15.42  39.87  20.33  25.06  33.47  3.11  0.74  3.79
# 3687  Patna  23-06-2020  20.71  57.47  25.82  26.84  36.15  4.76  0.86  3.75
# 3688  Patna  24-06-2020  25.62  55.48  22.42  25.52  33.97  2.74  0.77  3.24
# 3689  Patna  25-06-2020  27.71  68.29  16.14  26.48  28.90  2.76  0.95  2.98
# 3690  Patna  26-06-2020  23.16  39.80  10.37  25.68  24.65  3.13  0.79  2.92
# 3691  Patna  27-06-2020  17.71  63.73   9.47  23.01  22.28  1.91  0.87  3.63
# 3692  Patna  28-06-2020  19.27  57.42  30.19  18.13  36.76  2.05  0.72  3.92
# 3693  Patna  29-06-2020  17.24  42.83  42.40  20.51  47.69  2.26  0.88  3.60
# 3694  Patna  30-06-2020  29.76  60.68  42.12  27.50  52.04  1.59  0.83  3.91
# 3695  Patna  01-07-2020  35.42  57.82  44.50  31.15  57.72  1.14  0.82  3.99
#
#          O3  Benzene  Toluene  Xylene  AQI    AQI_Bucket
# 3686  20.83     1.76     4.13    1.28   60  Satisfactory
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        3696 non-null   object
#  1   Date        3696 non-null   object
#  2   PM2.5       3696 non-null   float64
#  3   PM10        3696 non-null   float64
#  4   NO          3696 non-null   float64
#  5   NO2         3696 non-null   float64
#  6   NOx         3696 non-null   float64
#  7   NH3         3696 non-null   float64
#  8   CO          3696 non-null   float64
#  9   SO2         3696 non-null   float64
#  10  O3          3696 non-null   float64
#  11  Benzene     3696 non-null   float64
#  12  Toluene     3696 non-null   float64
#  13  Xylene      3696 non-null   float64
#  14  AQI         3696 non-null   int64
#  15  AQI_Bucket  3696 non-null   object
# dtypes: float64(12), int64(1), object(3)
# memory usage: 462.1+ KB

# %%
df.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  3696.000000  3696.000000  3696.000000  3696.000000  3696.000000
# mean     85.629180   167.305111    26.252936    41.523217    43.112900
# std      73.835435   116.369689    30.399572    21.702810    35.328858
# min       5.560000    10.540000     1.220000     0.620000     1.580000
# 25%      38.587500    85.477500     7.097500    25.747500    17.530000
# 50%      62.830000   129.485000    12.870000    38.370000    30.785000
# 75%     107.362500   223.415000    33.592500    53.207500    58.970000
# max     685.360000   796.880000   221.030000   162.500000   254.800000
#
#                NH3           CO          SO2           O3      Benzene  \
# count  3696.000000  3696.000000  3696.000000  3696.000000  3696.000000
# mean     29.707321     1.365346    12.806756    43.210736     2.572508
# std      18.970456     2.019167     8.357289    22.873801     2.283232
# ...

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
df.AQI_Bucket.unique()
# Out:
# array(['Severe', 'Moderate', 'Very Poor', 'Poor', 'Satisfactory', 'Good'],
#       dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.plot(kind="box",subplots=True,sharex=False, sharey=False,layout=(4,4),figsize=(20,20))
# Out:
# PM2.5          AxesSubplot(0.125,0.71587;0.168478x0.16413)
# PM10        AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# NO          AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# NO2         AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# NOx           AxesSubplot(0.125,0.518913;0.168478x0.16413)
# NH3        AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# CO         AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# SO2        AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# O3            AxesSubplot(0.125,0.321957;0.168478x0.16413)
# Benzene    AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# Toluene    AxesSubplot(0.529348,0.321957;0.168478x0.16413)
# Xylene     AxesSubplot(0.731522,0.321957;0.168478x0.16413)
# AQI              AxesSubplot(0.125,0.125;0.168478x0.16413)
# dtype: object

# %%
df.AQI_Bucket.value_counts()
# Out:
# Moderate        1400
# Satisfactory     784
# Poor             608
# Very Poor        534
# Severe           244
# Good             126
# Name: AQI_Bucket, dtype: int64

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
df=df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
 df.AQI_Bucket=df.AQI_Bucket.fillna(df.AQI_Bucket.mode()[0])

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
lst=[]
for i in df.columns:
    if df[i].dtype=="float":
        lst.append(i)
lst
# Out:
# ['PM2.5',
#  'PM10',
#  'NO',
#  'NO2',
#  'NOx',
#  'NH3',
#  'CO',
#  'SO2',
#  'O3',
#  'Benzene',
#  'Toluene',
#  'Xylene']

# %%
df.AQI_Bucket.unique()
# Out:
# array(['Severe', 'Moderate', 'Very Poor', 'Poor', 'Satisfactory', 'Good'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
for i in lst:
    df[i]=lb.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        3696 non-null   object
#  1   Date        3696 non-null   object
#  2   PM2.5       3696 non-null   int64
#  3   PM10        3696 non-null   int64
#  4   NO          3696 non-null   int64
#  5   NO2         3696 non-null   int64
#  6   NOx         3696 non-null   int64
#  7   NH3         3696 non-null   int64
#  8   CO          3696 non-null   int64
#  9   SO2         3696 non-null   int64
#  10  O3          3696 non-null   int64
#  11  Benzene     3696 non-null   int64
#  12  Toluene     3696 non-null   int64
#  13  Xylene      3696 non-null   int64
#  14  AQI         3696 non-null   int64
#  15  AQI_Bucket  3696 non-null   object
# dtypes: int64(13), object(3)
# memory usage: 462.1+ KB

# %%
df
# Out:
#        City        Date  PM2.5  PM10    NO   NO2   NOx   NH3   CO  SO2    O3  \
# 0     Delhi  01-01-2015   3213  3463  2173  1279  2774  1564  472  581  1481
# 1     Delhi  02-01-2015   2920  2806  2086  1093  2594  1452  409  342   788
# 2     Delhi  03-01-2015   2158  1718  1418   954  1828  2533  433   14   260
# 3     Delhi  04-01-2015   2747  2662  1399  1310  1849  2629  448  153   516
# 4     Delhi  05-01-2015   2707  2535   955  1203  1586  2625  398   54   403
# ...     ...         ...    ...   ...   ...   ...   ...   ...  ...  ...   ...
# 3691  Patna  27-06-2020    224   512   635   588   911     3   86   69   417
# 3692  Patna  28-06-2020    262   417  1536   369  1539     4   71   95   177
# 3693  Patna  29-06-2020    212   231  1807   473  1821     5   87   68   179
# 3694  Patna  30-06-2020    525   460  1800   817  1929     1   82   94   338
# 3695  Patna  01-07-2020    705   423  1845  1000  2086     0   81  100   536
#
# ...

# %%
df.head(10)
# Out:
#     City        Date  PM2.5  PM10    NO   NO2   NOx   NH3   CO  SO2    O3  \
# 0  Delhi  01-01-2015   3213  3463  2173  1279  2774  1564  472  581  1481
# 1  Delhi  02-01-2015   2920  2806  2086  1093  2594  1452  409  342   788
# 2  Delhi  03-01-2015   2158  1718  1418   954  1828  2533  433   14   260
# 3  Delhi  04-01-2015   2747  2662  1399  1310  1849  2629  448  153   516
# 4  Delhi  05-01-2015   2707  2535   955  1203  1586  2625  398   54   403
# 5  Delhi  06-01-2015   2726  2720  1102  1357  1691  2633  406   72   597
# 6  Delhi  07-01-2015   3042  3223  1459  1470  1940  2632  417  264   719
# 7  Delhi  08-01-2015   3071  3178  1337  1615  1911  2636  439   52   816
# 8  Delhi  09-01-2015   2985  3273  1192  1400  1774  2637  440   61   969
# 9  Delhi  10-01-2015   3052  3182  1390  1783  2017  2631  415  273  1041
#
#    Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0      790     1622     645  472     Severe
# 1      770     1415     403  454     Severe
# ...

# %%
df.tail(50)
# Out:
#        City        Date  PM2.5  PM10    NO   NO2   NOx  NH3  CO   SO2    O3  \
# 3646  Patna  13-05-2020    935   998  2222  1159  2460  219  74   809  1518
# 3647  Patna  14-05-2020   1260  2071  1905  1030  2279  262  76   413  1434
# 3648  Patna  15-05-2020    625   888  1715   427  2028  386  54   237  1277
# 3649  Patna  16-05-2020   1165  1514  2049  1089  2415  319  68   454  1380
# 3650  Patna  17-05-2020   1215  2840  2025  1190  2628  230  75  1201  1788
# 3651  Patna  18-05-2020   1084  1615  1966   929  2457  243  71   435  1780
# 3652  Patna  19-05-2020    951  1415  1920   348  2073  260  56   189  1718
# 3653  Patna  20-05-2020    619  1141  2009   359  2015  183  50   337  1274
# 3654  Patna  21-05-2020    263   362  2024   563  2002   32  41   182  1377
# 3655  Patna  22-05-2020    131   386  2014   377  1994  120  36   591  1447
# 3656  Patna  23-05-2020    422   649  2105   357  2116  166  51   274   924
# ...

# %%
lst=[]
for i in df.columns:
    if df[i].dtype=='O':
        lst.append(i)
lst
# Out:
# ['City', 'Date', 'AQI_Bucket']

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
for i in lst:
    df[i]=lb.fit_transform(df[i])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        3696 non-null   int32
#  1   Date        3696 non-null   int32
#  2   PM2.5       3696 non-null   int64
#  3   PM10        3696 non-null   int64
#  4   NO          3696 non-null   int64
#  5   NO2         3696 non-null   int64
#  6   NOx         3696 non-null   int64
#  7   NH3         3696 non-null   int64
#  8   CO          3696 non-null   int64
#  9   SO2         3696 non-null   int64
#  10  O3          3696 non-null   int64
#  11  Benzene     3696 non-null   int64
#  12  Toluene     3696 non-null   int64
#  13  Xylene      3696 non-null   int64
#  14  AQI         3696 non-null   int64
#  15  AQI_Bucket  3696 non-null   int32
# dtypes: int32(3), int64(13)
# memory usage: 418.8 KB

# %%
x=df.drop("AQI_Bucket",axis=1)
y=df.AQI_Bucket

# %%
x.head(10)
# Out:
#    City  Date  PM2.5  PM10    NO   NO2   NOx   NH3   CO  SO2    O3  Benzene  \
# 0     0     0   3213  3463  2173  1279  2774  1564  472  581  1481      790
# 1     0    67   2920  2806  2086  1093  2594  1452  409  342   788      770
# 2     0   132   2158  1718  1418   954  1828  2533  433   14   260      389
# 3     0   198   2747  2662  1399  1310  1849  2629  448  153   516      424
# 4     0   264   2707  2535   955  1203  1586  2625  398   54   403      279
# 5     0   330   2726  2720  1102  1357  1691  2633  406   72   597      362
# 6     0   396   3042  3223  1459  1470  1940  2632  417  264   719      486
# 7     0   462   3071  3178  1337  1615  1911  2636  439   52   816      555
# 8     0   528   2985  3273  1192  1400  1774  2637  440   61   969      514
# 9     0   594   3052  3182  1390  1783  2017  2631  415  273  1041      480
#
#    Toluene  Xylene  AQI
# 0     1622     645  472
# 1     1415     403  454
# 2      881     198  143
# 3      844     321  319
# ...

# %%
y.head(10)
# Out:
# 0    4
# 1    4
# 2    1
# 3    5
# 4    5
# 5    5
# 6    5
# 7    5
# 8    5
# 9    5
# Name: AQI_Bucket, dtype: int32

# %%
x
# Out:
#       City  Date  PM2.5  PM10    NO   NO2   NOx   NH3   CO  SO2    O3  \
# 0        0     0   3213  3463  2173  1279  2774  1564  472  581  1481
# 1        0    67   2920  2806  2086  1093  2594  1452  409  342   788
# 2        0   132   2158  1718  1418   954  1828  2533  433   14   260
# 3        0   198   2747  2662  1399  1310  1849  2629  448  153   516
# 4        0   264   2707  2535   955  1203  1586  2625  398   54   403
# ...    ...   ...    ...   ...   ...   ...   ...   ...  ...  ...   ...
# 3691     2  1750    224   512   635   588   911     3   86   69   417
# 3692     2  1815    262   417  1536   369  1539     4   71   95   177
# 3693     2  1877    212   231  1807   473  1821     5   87   68   179
# 3694     2  1937    525   460  1800   817  1929     1   82   94   338
# 3695     2    41    705   423  1845  1000  2086     0   81  100   536
#
#       Benzene  Toluene  Xylene  AQI
# 0         790     1622     645  472
# 1         770     1415     403  454
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3696 entries, 0 to 3695
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     3696 non-null   int32
#  1   Date     3696 non-null   int32
#  2   PM2.5    3696 non-null   int64
#  3   PM10     3696 non-null   int64
#  4   NO       3696 non-null   int64
#  5   NO2      3696 non-null   int64
#  6   NOx      3696 non-null   int64
#  7   NH3      3696 non-null   int64
#  8   CO       3696 non-null   int64
#  9   SO2      3696 non-null   int64
#  10  O3       3696 non-null   int64
#  11  Benzene  3696 non-null   int64
#  12  Toluene  3696 non-null   int64
#  13  Xylene   3696 non-null   int64
#  14  AQI      3696 non-null   int64
# dtypes: int32(2), int64(13)
# memory usage: 404.4 KB

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix
model_lr=LogisticRegression()
model_lr.fit(X_train,y_train)
pred_lr=model_lr.predict(X_test)
accuracy_score(y_test,pred_lr)
# Out:
# 0.6456266907123535

# %%
confusion_matrix(y_test,pred_lr)
# Out:
# array([[ 17,   0,   0,  10,   0,   0],
#        [  2, 341,  36,  45,   3,  10],
#        [  0,  64,  81,   1,   2,  41],
#        [ 10,  73,   4, 137,   1,   1],
#        [  0,   1,   3,   0,  43,  21],
#        [  0,   9,  43,   0,  13,  97]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf=RandomForestClassifier()
model_rf.fit(X_train,y_train)
pred_rf=model_rf.predict(X_test)
accuracy_score(y_test,pred_rf)
# Out:
# 0.9927862939585211

# %%
confusion_matrix(y_test,pred_rf)
# Out:
# array([[ 27,   0,   0,   0,   0,   0],
#        [  0, 437,   0,   0,   0,   0],
#        [  0,   0, 189,   0,   0,   0],
#        [  0,   0,   0, 226,   0,   0],
#        [  0,   0,   0,   0,  67,   1],
#        [  0,   0,   6,   0,   1, 155]], dtype=int64)

# %%
X_test
# Out:
#       City  Date  PM2.5  PM10    NO   NO2   NOx   NH3   CO   SO2    O3  \
# 1041     0   543   2615  2835  1861  2485  2443  2100  163  1314  1993
# 670      0   783   3169  3353  2477  2891  1999  2589  148  1757  1568
# 315      0   848   3189  3390  1471  2368  2558  2243  174  1450  2708
# 2958     1    71   1831  2016  1184  2523  1891   581  102   943  1000
# 1610     0  1892    201   322   522   584   778   947   73   544   389
# ...    ...   ...    ...   ...   ...   ...   ...   ...  ...   ...   ...
# 350      0  1183   2638  3402  1910   701  2195  2496  151  1380   303
# 1936     1   584   1261  1522   440   294   874   393   58   498  1394
# 2325     1    20    988  1508   602   990   216   542   13   291  2268
# 2876     1   780   1274  1722   373  1599  1129   780   52   947   656
# 1580     0  1947    967  1279   892  1073  1298  1552  101   589  1344
#
#       Benzene  Toluene  Xylene  AQI
# 1041      451      595     391  316
# 670       511     1321     551  491
# ...

# %%
y_test
# Out:
# 1041    5
# 670     4
# 315     4
# 2958    1
# 1610    3
#        ..
# 350     5
# 1936    1
# 2325    1
# 2876    1
# 1580    1
# Name: AQI_Bucket, Length: 1109, dtype: int32

# %%
pred_rf
# Out:
# array([5, 4, 4, ..., 1, 1, 1])

# %% [markdown]
# # Final Result

# %% [markdown]
# The result is that the acutal values and predicted values are same

# %%
data1=pd.DataFrame(pred_rf,y_test)

# %%
data1
# Out:
#             0
# AQI_Bucket
# 5           5
# 4           4
# 4           4
# 1           1
# 3           3
# ...        ..
# 5           5
# 1           1
# 1           1
# 1           1
# 1           1
#
# [1109 rows x 1 columns]
